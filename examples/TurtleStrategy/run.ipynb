# %%
# %matplotlib inline

from datetime import datetime

import numpy as np
import matplotlib.pyplot as plt

from turtleEngine import BacktestingEngine

# %%
engine = BacktestingEngine()
engine.setPeriod(datetime(2013, 11, 1), datetime(2018, 12, 30))
engine.initPortfolio('setting88.csv', 10000000)

engine.loadData()
engine.runBacktesting()
engine.showResult()
# Out:
# 投资组合的合约代码['IF88', 'I88', 'RB88', 'TA88']
# 投资组合的初始价值10000000
# IF88数据加载完成，总数据量：1263
# I88数据加载完成，总数据量：1263
# RB88数据加载完成，总数据量：1263
# TA88数据加载完成，总数据量：1263
# 全部数据加载完成
# 开始回放K线数据
# K线数据回放结束
# 开始统计回测结果
# ------------------------------
# 首个交易日：	2013-11-01 00:00:00
# 最后交易日：	2018-12-28 00:00:00
# 总交易日：	1263
# 盈利交易日	564
# 亏损交易日：	561
# 起始资金：	10000000
# 结束资金：	70,068,855.74
# 总收益率：	600.69%
# 年化收益：	40.14%
# 总盈亏：	60,068,855.74
# 最大回撤: 	-9,810,777.27
# 百分比最大回撤: -26.08%
# 总手续费：	843,967.06
# 总滑点：	153,077.2
# 总成交笔数：	597.0
# 日均盈亏：	47,560.46
# 日均手续费：	668.22
# 日均滑点：	121.2
# 日均成交笔数：	0.0
# 日均收益率：	0.17%
# 收益标准差：	1.63%
# Sharpe Ratio：	1.59

# %%
tradeList = engine.getTradeData('IF99')
for trade in tradeList:
    print '%s %s %s %s@%s' %(trade.vtSymbol, trade.direction, trade.offset,
                             trade.volume, trade.price)
